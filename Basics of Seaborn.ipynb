# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="day")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="day", col="time", row="sex")

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="size")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=tips, x="total_bill", y="tip",hue="size")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.displot(data=tips, x="total_bill",kde=True)

# %%
sns.displot(data=tips, x="total_bill", y="tip")

# %%
sns.displot(data=tips, x="total_bill", y="tip",kind='kde')

# %%
sns.histplot(data=tips, x="total_bill", bins=30)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips, x="total_bill", bins=30,hue="size")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(data=tips, x="total_bill", hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.ecdfplot(data=tips, x="total_bill", hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='Proportion'>

# %%
sns.catplot(data=tips, x="total_bill", y="time")

# %%
sns.catplot(data=tips, x="total_bill", y="time",hue="size")

# %%
sns.stripplot(data=tips, x="total_bill", y="day",hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.swarmplot(data=tips, x="total_bill", y="day", hue="day", legend=False)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.boxplot(data=tips, x="total_bill", y="day", hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(data=tips, x="total_bill", y="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(data=tips, x="total_bill", y="day",hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.boxenplot(data=tips, x="total_bill", y="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.pointplot(data=tips, x="total_bill", y="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.barplot(data=tips, x="total_bill", y="day",hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.barplot(data=tips, x="total_bill", y="day",hue="time")

# %%
sns.countplot(data=tips, x="total_bill",hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='count'>

# %%
sns.lmplot(data=tips, x="total_bill",y="tip",hue="size")

# %%
sns.regplot(data=tips, x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.residplot(data=tips, x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
